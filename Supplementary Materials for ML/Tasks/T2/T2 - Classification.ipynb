# %% [markdown]
# Name: **Robb Ryan P. Calvez**
# Year & Section: **BS CpE 3A**
# Course: **Computer Engineering - Artificial Intelligence / Machine Learning**
#
# **TASK 2: Classification**
#
# **Scenario:**<p>
# A manufacturing plant operates dozens of three-phase induction motors that drive critical conveyor lines
# on its production floor. Unplanned motor failures cause costly downtime, so the maintenance team has
# installed vibration and stator-current sensors on every motor. They want an automated diagnostic system
# that not only flags whether a motor is unhealthy but also identifies the specific type of fault from real-time
# sensor readings, so technicians can prepare the correct replacement parts before scheduling shutdowns.
# Five-second sensor windows are summarized into engineered features that feed the model.
# </p>
#
#
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# ##### **Step 1: Import Libraries**

# %%
import tensorflow as tf 
import pandas as pd 
import numpy as np 
import sklearn
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


print(f'tensorflow: {tf.__version__}\n', 
      f'pandas: {pd.__version__}\n',
      f'numpy: {np.__version__}\n',
      f'sklearn: {sklearn.__version__}')
# Out:
# tensorflow: 2.21.0
#  pandas: 3.0.2
#  numpy: 2.4.2
#  sklearn: 1.8.0
